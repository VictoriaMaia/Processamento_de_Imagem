# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# from mpl_toolkits import mplot3d

# %% [markdown]
# # Questão 1

# %%
img1 = cv2.imread('imagens_prova/1.jpg')
img1_hsv = cv2.cvtColor(img1, cv2.COLOR_BGR2HSV)

# %%
plt.imshow(img1);

# %%
low_blue = np.array([10,60,100])
high_blue = np.array([90,120,255])
mask2 = cv2.inRange(img1_hsv, low_blue, high_blue)
plt.imshow(mask2);

# %%
low_green = np.array([20, 155, 45])
high_green = np.array([110, 255, 255])
mask = cv2.inRange(img1_hsv, low_green, high_green)
plt.imshow(mask);

# %%
green = cv2.bitwise_and(img1, img1_hsv, mask=mask)
plt.imshow(green);

# %%
blue = cv2.bitwise_and(img1, img1_hsv, mask=mask2)
plt.imshow(blue);

# %%
final = cv2.add(green, blue)
# final = cv2.add(final, img1)
plt.imshow(final);

# %% [markdown]
# # Questão 2

# %%
img2 = cv2.imread('imagens_prova/2.jpg', 0)
plt.imshow(img2, 'gray');

# %%
img2 = cv2.bitwise_not(img2)
plt.imshow(img2, 'gray');

# %%
elem_type_rect = cv2.MORPH_RECT
element_rect = cv2.getStructuringElement(elem_type_rect, (2, 5))

# %%
kernel = np.ones((20,20),np.uint8)

# %%
gradient = cv2.morphologyEx(closing, cv2.MORPH_GRADIENT, kernel)
plt.imshow(gradient,'gray')

# %%
closing = cv2.morphologyEx(img2, cv2.MORPH_CLOSE, kernel)
plt.imshow(closing, 'gray')

# %%
dilation = cv2.dilate(closing, element_rect)
plt.imshow(dilation, 'gray');

# %%
for i in range(0,2):
    dilation = cv2.dilate(dilation, element_rec2)
plt.imshow(dilation, 'gray');

# %%
erosion = cv2.erode(gradient, element_rect)
plt.imshow(erosion, 'gray');

# %%
for i in range(0, 10):
    erosion = cv2.erode(erosion, element_rect)
plt.imshow(erosion, 'gray');
# 10

# %%
dilation = cv2.dilate(erosion, element_rect)
plt.imshow(dilation, 'gray');

# %%
for i in range(0,10):
    dilation = cv2.dilate(dilation, element_rec2)
plt.imshow(dilation, 'gray');

# %%
final = cv2.bitwise_and(img2, dilation)
plt.imshow(final, 'gray');

# %%
# final = cv2.subtract(img2, final)
plt.imshow(img2, 'gray');

# %% [markdown]
# # Questão 3

# %%
img3 = cv2.imread('imagens_prova/3.jpg', 0)
plt.imshow(img3, 'gray');

# %%
img3.shape
# Out:
# (474, 473, 3)

# %%
width = img3.shape[1]
height = img3.shape[0]

# %%
rotacao90 = cv2.getRotationMatrix2D((238,236),90,1)
img3_rotacionada90 = cv2.warpAffine(img3,rotacao90,(width,height), borderValue=255)
plt.imshow(img3_rotacionada90, 'gray');

# %%
img3_escala2x = cv2.resize(img3,(width*2,height*2))
plt.imshow(img3_escala2x, 'gray');

# %%
M_translation = np.float32([[1,0,100],[0,1,50]])
M_scaling = np.float32([[.8,0,1], [0,.9,1]])

img3_transladada = cv2.warpAffine(img3,M_scaling,(width,height))
img3_transladada = cv2.warpAffine(img3_transladada, M_translation, (width,height))

plt.imshow(img3_transladada, 'gray');

# %%
fft_img3 = np.fft.fft2(img3)
fft_img3_shift = np.fft.fftshift(fft_img3)
plt.imshow(np.log(np.abs(fft_img3_shift)+1), 'gray');

# %%
fft_img3_rot90 = np.fft.fft2(img3_rotacionada90)
fft_img3_rot90_shift = np.fft.fftshift(fft_img3_rot90)
plt.imshow(np.log(np.abs(fft_img3_rot90_shift)+1), 'gray');

# %%
fft_img3_esc = np.fft.fft2(img3_escala2x)
fft_img3_esc_shift = np.fft.fftshift(fft_img3_esc)
plt.imshow(np.log(np.abs(fft_img3_esc_shift)+1), 'gray');

# %%
fft_img3_tran = np.fft.fft2(img3_transladada)
fft_img3_tran_shift = np.fft.fftshift(fft_img3_tran)
plt.imshow(np.log(np.abs(fft_img3_tran_shift)+1), 'gray');

# %%
plt.figure(figsize=[10,10])
plt.subplot(221), plt.imshow(np.log(np.abs(fft_img3_shift)+1), 'gray'), plt.title('Original')
plt.subplot(222), plt.imshow(np.log(np.abs(fft_img3_rot90_shift)+1), 'gray'),plt.title('Rotacionada')
plt.subplot(223), plt.imshow(np.log(np.abs(fft_img3_esc_shift)+1), 'gray'), plt.title('Escalonada')
plt.subplot(224), plt.imshow(np.log(np.abs(fft_img3_tran_shift)+1), 'gray'),plt.title('Transladada')
plt.show()

# %% [markdown]
# - As baixas frequências da imagem rotacionada mudaram de posição.
# - Na imagem escalonada tem um aumento de frequencias altas.

# %% [markdown]
# # Questão 4

# %%
img4 = cv2.imread('imagens_prova/4.jpeg', 0)
plt.imshow(img4, 'gray');

# %%
# custom kernel (media 3x3)
kernel_media = np.float32([[1,1,1],[1,1,1],[1,1,1]])/9
customMedia = cv2.filter2D(img4,-1,kernel_media)

# custom realcar as bordas (media - imagem)
plt.figure(figsize=[10,10])
customBordas = cv2.subtract(img4, customMedia)
# customBordas = cv2.bitwise_not(customBordas)
plt.imshow(customBordas, 'gray');

# %%
# custom realcar as bordas na imagem (img + customBordas)
plt.figure(figsize=[10,10])
custom = cv2.add(img4, customBordas)
plt.imshow(custom, 'gray');

# %%
cv2.getGaborKernel()
