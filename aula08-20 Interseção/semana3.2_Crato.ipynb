# %% [markdown]
# # Aula 20/08
# ## Ajuste parecido com panorama

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
im1 = cv2.imread('images/pt1.jpg', 0)
# im1 = cv2.cvtColor(im1, cv2.COLOR_BGR2RGB)
plt.imshow(im1, 'gray')

# %%
im2 = cv2.imread('images/pt2.jpg', 0)
# im2 = cv2.cvtColor(im2, cv2.COLOR_BGR2RGB)
plt.imshow(im2, 'gray')

# %%
im1.shape, im2.shape
# Out:
# ((480, 640), (480, 639))

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error

# %%
print(mse(im1, im1))
# Out:
# 0.0

# %%
plt.imshow(im1[:, -100:], 'gray')

# %%
plt.imshow(im2[:, :100], 'gray')

# %%
for i in range(0, 400, 1):
    res = mse(im1[:, -100:], im2[:, i:(i+100)])
    
    if res == 0:
        print('Deu bom no i = '+str(i))
        break
# Out:
# Deu bom no i = 220

# %%
M_translacao = np.float32([[1,0,-i-100], [0,1,0]])
M_translacao
# Out:
# array([[   1.,    0., -320.],
#        [   0.,    1.,    0.]], dtype=float32)

# %%
deslocamento = i+100

# %%
im_translated = cv2.warpAffine(im2, M_translacao, (640-(deslocamento),480))
plt.imshow(im_translated, 'gray')

# %%
plt.figure(figsize=(10,10))
plt.subplot(211), plt.imshow(im1, 'gray')
plt.subplot(212), plt.imshow(im2[:, deslocamento:], 'gray')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f5307932080>,
#  <matplotlib.image.AxesImage at 0x7f53077e55f8>)

# %%
im_concat = np.concatenate((im1, im_translated), axis=1)
print(im_concat.shape)
plt.figure(figsize=(10,10))
plt.imshow(im_concat, 'gray')
# Out:
# (480, 960)

# %%
a = cv2.imread('images/alpaca.jpg', 0)
a.shape
# Out:
# (480, 960)

# %%
a = [1, 2, 3, 4, 5, 6]
a[-3:]
# Out:
# [4, 5, 6]
